# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import os
dataset_path = "/kaggle/input/datasets/saitejaswinichikoti/mendeley/Indian Medicinal Leaves Image Datasets/Medicinal Leaf dataset"
for label in os.listdir(dataset_path):
    label_path = os.path.join(dataset_path, label)
    if os.path.isdir(label_path):
        count = len(os.listdir(label_path))
        # print(label, count)
        print(label)
# Out:
# Tecoma
# Malabar_Nut
# Curry
# Drumstick
# Tomato
# Lemongrass
# Ginger
# Chilly
# Nelavembu
# Raddish
# Nooni
# Jackfruit
# Turmeric
# Palak(Spinach)
# Honge
# Mint
# Pumpkin
# Lantana
# Jasmine
# Castor
# Papaya
# Sapota
# Kambajala
# Kasambruga
# Badipala
# Neem
# Guava
# Bringaraja
# kamakasturi
# Coriender
# Coffee
# ashoka
# Tulsi
# Pea
# Seethapala
# Caricature
# Citron lime (herelikai)
# Catharanthus
# Astma_weed
# Pepper
# Balloon_Vine
# Hibiscus
# Bhrami
# Pomoegranate
# Aloevera
# Chakte
# Eucalyptus
# Beans
# Insulin
# camphor
# Padri
# Parijatha
# Marigold
# Taro
# Spinach1
# Bamboo
# Amla
# Arali
# kepala
# Globe Amarnath
# Ganigale
# Lemon
# Common rue(naagdalli)
# Ekka
# Betel
# Tamarind
# Henna
# Gasagase
# Doddpathre
# Malabar_Spinach
# Rose
# Amruthaballi
# Kohlrabi
# Nerale
# Mango
# Onion
# Thumbe
# Sampige
# Ganike
# Seethaashoka

# %%
import os
dataset_path = "/kaggle/input/datasets/saitejaswinichikoti/medicinal-leaf-dataset/Medicinal Leaf Dataset/Segmented Medicinal Leaf Images"
for label in os.listdir(dataset_path):
    label_path = os.path.join(dataset_path, label)
    if os.path.isdir(label_path):
        count = len(os.listdir(label_path))
        # print(label, count)
        print(label )
# Out:
# Murraya Koenigii (Curry)
# Nyctanthes Arbor-tristis (Parijata)
# Plectranthus Amboinicus (Mexican Mint)
# Punica Granatum (Pomegranate)
# Ficus Religiosa (Peepal Tree)
# Muntingia Calabura (Jamaica Cherry-Gasagase)
# Tabernaemontana Divaricata (Crape Jasmine)
# Psidium Guajava (Guava)
# Ocimum Tenuiflorum (Tulsi)
# Moringa Oleifera (Drumstick)
# Brassica Juncea (Indian Mustard)
# Nerium Oleander (Oleander)
# Carissa Carandas (Karanda)
# Santalum Album (Sandalwood)
# Artocarpus Heterophyllus (Jackfruit)
# Mentha (Mint)
# Citrus Limon (Lemon)
# Alpinia Galanga (Rasna)
# Piper Betle (Betel)
# Basella Alba (Basale)
# Pongamia Pinnata (Indian Beech)
# Mangifera Indica (Mango)
# Amaranthus Viridis (Arive-Dantu)
# Trigonella Foenum-graecum (Fenugreek)
# Jasminum (Jasmine)
# Syzygium Jambos (Rose Apple)
# Ficus Auriculata (Roxburgh fig)
# Azadirachta Indica (Neem)
# Syzygium Cumini (Jamun)
# Hibiscus Rosa-sinensis

# %%
import os
dataset_path = "/kaggle/input/datasets/saitejaswinichikoti/south-indian-medicinal-plant-dataset/SIMPD V1 South Indian Medicinal Plants dataset (Version 1)"
for label in os.listdir(dataset_path):
    label_path = os.path.join(dataset_path, label)
    if os.path.isdir(label_path):
        count = len(os.listdir(label_path))
        # print(label, count)
        print(label)
# Out:
# Hibiscus Rosasinensis
# Curcuma longa
# Abutilon Indicum
# Ziziphus mauritiana
# Ouretlanata
# Canna indica
# Ocimum tenuiflorum
# Trifolium Repens
# Eclipta prostrate
# Phyllanthus amarus
# Calotropis gigantea
# Murraya koenigii
# Ixora coccinea
# Sesbania grandiflora
# Ricinus communis
# Justica adhatoda
# Aloe barbadensis miller
# Senna Atriculata
# Cissus quadrangularis
# Eichhornia Crassipes

# %%
#Medicinal_leaf_dataset(leafs , 30 dir ,scientific name(common name))
df2 = "/kaggle/input/datasets/saitejaswinichikoti/medicinal-leaf-dataset/Medicinal Leaf Dataset/Segmented Medicinal Leaf Images"
#Mendeley[ayurleaf](leafs , 80 dir , common name)
df3 = "/kaggle/input/datasets/saitejaswinichikoti/mendeley/Indian Medicinal Leaves Image Datasets/Medicinal Leaf dataset"
#SIMPD(mixed , 20 dir , scientific name)
df4 = "/kaggle/input/datasets/saitejaswinichikoti/south-indian-medicinal-plant-dataset/SIMPD V1 South Indian Medicinal Plants dataset (Version 1)"

# %%
# Medicinal Leaf Dataset [ 30 Dir ]

# Murraya Koenigii 		(Curry)
# Nyctanthes Arbor-tristis 	(Parijata)
# Plectranthus Amboinicus 	(Mexican Mint)
# Punica Granatum 		(Pomegranate)
# Ficus Religiosa 		(Peepal Tree)
# Muntingia Calabura 		(Jamaica Cherry-Gasagase)
# Tabernaemontana Divaricata 	(Crape Jasmine)
# Psidium Guajava 		(Guava)
# Ocimum Tenuiflorum 		(Tulsi)
# Moringa Oleifera 		(Drumstick)
# Brassica Juncea 		(Indian Mustard)
# Nerium Oleander 		(Oleander)
# Carissa Carandas 		(Karanda)
# Santalum Album 			(Sandalwood)
# Artocarpus Heterophyllus 	(Jackfruit)
# Mentha 				(Mint)
# Citrus Limon 			(Lemon)
# Alpinia Galanga 		(Rasna)
# Piper Betle 			(Betel)
# Basella Alba 			(Basale)
# Pongamia Pinnata 		(Indian Beech)
# Mangifera Indica 		(Mango)
# Amaranthus Viridis 		(Arive-Dantu)
# Trigonella Foenum-graecum 	(Fenugreek)
# Jasminum 			(Jasmine)
# Syzygium Jambos 		(Rose Apple)
# Ficus Auriculata 		(Roxburgh fig)
# Azadirachta Indica 		(Neem)
# Syzygium Cumini 		(Jamun)
# Hibiscus Rosa-sinensis		(Hibiscus)

# %%
import shutil
import os

folders_to_clear = [
    "/kaggle/working/Medicinal_Leaf_Dataset",
    "/kaggle/working/Mendeley_Dataset", 
    "/kaggle/working/SIMPD_Dataset"
]

for folder in folders_to_clear:
    if os.path.exists(folder):
        shutil.rmtree(folder)
        print(f"Cleared: {folder}")
    else:
        print(f"Doesn't exist, skipping: {folder}")
# Out:
# Doesn't exist, skipping: /kaggle/working/Medicinal_Leaf_Dataset
# Doesn't exist, skipping: /kaggle/working/Mendeley_Dataset
# Doesn't exist, skipping: /kaggle/working/SIMPD_Dataset

# %%
import os
import re
import shutil

df2 = "/kaggle/input/datasets/saitejaswinichikoti/medicinal-leaf-dataset/Medicinal Leaf Dataset/Segmented Medicinal Leaf Images"
df2_output = "/kaggle/working/Medicinal_Leaf_Dataset"

if os.path.exists(df2_output):
    shutil.rmtree(df2_output)
os.makedirs(df2_output)

def standardize_name(name):
    name = re.sub(r'\(.*?\)', '', name).strip()
    return name.replace("-", "_").replace(" ", "_").lower().strip()

scientific_names_df2 = []

for label in os.listdir(df2):
    label_path = os.path.join(df2, label)
    if os.path.isdir(label_path):
        scientific_name = standardize_name(label)
        scientific_names_df2.append(scientific_name)
        dest_path = os.path.join(df2_output, scientific_name)
        shutil.copytree(label_path, dest_path)
        print(f"Copied: {label} --> {scientific_name}")

scientific_names_df2 = list(set(scientific_names_df2))
print("\nFinal scientific names list df2:")
print(scientific_names_df2)
# Out:
# Copied: Murraya Koenigii (Curry) --> murraya_koenigii
# Copied: Nyctanthes Arbor-tristis (Parijata) --> nyctanthes_arbor_tristis
# Copied: Plectranthus Amboinicus (Mexican Mint) --> plectranthus_amboinicus
# Copied: Punica Granatum (Pomegranate) --> punica_granatum
# Copied: Ficus Religiosa (Peepal Tree) --> ficus_religiosa
# Copied: Muntingia Calabura (Jamaica Cherry-Gasagase) --> muntingia_calabura
# Copied: Tabernaemontana Divaricata (Crape Jasmine) --> tabernaemontana_divaricata
# Copied: Psidium Guajava (Guava) --> psidium_guajava
# Copied: Ocimum Tenuiflorum (Tulsi) --> ocimum_tenuiflorum
# Copied: Moringa Oleifera (Drumstick) --> moringa_oleifera
# Copied: Brassica Juncea (Indian Mustard) --> brassica_juncea
# Copied: Nerium Oleander (Oleander) --> nerium_oleander
# Copied: Carissa Carandas (Karanda) --> carissa_carandas
# Copied: Santalum Album (Sandalwood) --> santalum_album
# Copied: Artocarpus Heterophyllus (Jackfruit) --> artocarpus_heterophyllus
# Copied: Mentha (Mint) --> mentha
# Copied: Citrus Limon (Lemon) --> citrus_limon
# Copied: Alpinia Galanga (Rasna) --> alpinia_galanga
# Copied: Piper Betle (Betel) --> piper_betle
# Copied: Basella Alba (Basale) --> basella_alba
# Copied: Pongamia Pinnata (Indian Beech) --> pongamia_pinnata
# Copied: Mangifera Indica (Mango) --> mangifera_indica
# Copied: Amaranthus Viridis (Arive-Dantu) --> amaranthus_viridis
# Copied: Trigonella Foenum-graecum (Fenugreek) --> trigonella_foenum_graecum
# Copied: Jasminum (Jasmine) --> jasminum
# Copied: Syzygium Jambos (Rose Apple) --> syzygium_jambos
# Copied: Ficus Auriculata (Roxburgh fig) --> ficus_auriculata
# Copied: Azadirachta Indica (Neem) --> azadirachta_indica
# Copied: Syzygium Cumini (Jamun) --> syzygium_cumini
# Copied: Hibiscus Rosa-sinensis --> hibiscus_rosa_sinensis
#
# Final scientific names list df2:
# ['punica_granatum', 'piper_betle', 'plectranthus_amboinicus', 'ocimum_tenuiflorum', 'citrus_limon', 'murraya_koenigii', 'syzygium_jambos', 'nyctanthes_arbor_tristis', 'hibiscus_rosa_sinensis', 'mentha', 'carissa_carandas', 'artocarpus_heterophyllus', 'syzygium_cumini', 'psidium_guajava', 'alpinia_galanga', 'nerium_oleander', 'ficus_auriculata', 'brassica_juncea', 'azadirachta_indica', 'santalum_album', 'trigonella_foenum_graecum', 'jasminum', 'ficus_religiosa', 'moringa_oleifera', 'pongamia_pinnata', 'amaranthus_viridis', 'muntingia_calabura', 'tabernaemontana_divaricata', 'mangifera_indica', 'basella_alba']

# %%
import os
import shutil

df3 = "/kaggle/input/datasets/saitejaswinichikoti/mendeley/Indian Medicinal Leaves Image Datasets/Medicinal Leaf dataset"
df3_output = "/kaggle/working/Mendeley_Dataset"

def standardize_name(name):
    return name.replace("-", "_").replace(" ", "_").lower().strip()

mapping = {
    "Tecoma": "Tecoma stans",
    "Malabar_Nut": "Adhatoda vasica",
    "Curry": "Murraya koenigii",
    "Drumstick": "Moringa oleifera",
    "Tomato": "Solanum lycopersicum",
    "Lemongrass": "Cymbopogon citratus",
    "Ginger": "Zingiber officinale",
    "Chilly": "Capsicum frutescens",
    "Nelavembu": "Andrographis paniculata",
    "Raddish": "Raphanus sativus",
    "Nooni": "Morinda citrifolia",
    "Jackfruit": "Artocarpus heterophyllus",
    "Turmeric": "Curcuma longa",
    "Palak(Spinach)": "Spinacia oleracea",
    "Honge": "Millettia pinnata",
    "Mint": "Mentha",
    "Pumpkin": "Cucurbita moschata",
    "Lantana": "Lantana camara",
    "Jasmine": "Jasminum",
    "Castor": "Ricinus communis",
    "Papaya": "Carica papaya",
    "Sapota": "Manilkara zapota",
    "Kambajala": "Cassia tora",
    "Neem": "Azadirachta indica",
    "Guava": "Psidium guajava",
    "Bringaraja": "Eclipta prostrata",
    "kamakasturi": "Ocimum basilicum",
    "Coriender": "Coriandrum sativum",
    "Coffee": "Coffea",
    "ashoka": "Saraca asoca",
    "Tulsi": "Ocimum tenuiflorum",
    "Pea": "Pisum",
    "Seethapala": "Annona reticulata",
    "Caricature": "Graptophyllum pictum",
    "Citron lime (herelikai)": "Citrus medica",
    "Catharanthus": "Catharanthus roseus",
    "Astma_weed": "Euphorbia hirta",
    "Pepper": "Piper nigrum",
    "Balloon_Vine": "Cardiospermum halicacabum",
    "Hibiscus": "Hibiscus rosa-sinensis",
    "Bhrami": "Bacopa monnieri",
    "Pomoegranate": "Punica granatum",
    "Aloevera": "Aloe barbadensis",
    "Eucalyptus": "Eucalyptus globulus",
    "Beans": "Phaseolus",
    "Insulin": "Chamaecostus cuspidatus",
    "camphor": "Cinnamomum camphora",
    "Padri": "Radermachera xylocarpa",
    "Parijatha": "Nyctanthes arbor-tristis",
    "Marigold": "Tagetes erecta",
    "Taro": "Colocasia esculenta",
    "Spinach1": "Spinacia oleracea",
    "Bamboo": "Bambusoideae",
    "Amla": "Phyllanthus emblica",
    "Arali": "Ficus religiosa",
    "kepala": "Ixora undulata",
    "Globe Amarnath": "Gomphrena globosa",
    "Ganigale": "Calotropis gigantea",
    "Lemon": "Citrus limon",
    "Common rue(naagdalli)": "Ruta graveolens",
    "Ekka": "Calotropis gigantea",
    "Betel": "Piper betle",
    "Tamarind": "Tamarindus indica",
    "Henna": "Lawsonia inermis",
    "Gasagase": "Papaver somniferum",
    "Doddpathre": "Coleus amboinicus",
    "Malabar_Spinach": "Basella alba",
    "Rose": "Rosa",
    "Amruthaballi": "Tinospora cordifolia",
    "Kohlrabi": "Brassica oleracea var. gongylodes",
    "Nerale": "Syzygium cumini",
    "Mango": "Mangifera indica",
    "Onion": "Allium cepa",
    "Thumbe": "Leucas aspera",
    "Sampige": "Magnolia champaca",
    "Ganike": "Solanum nigrum",
}

if os.path.exists(df3_output):
    shutil.rmtree(df3_output)
os.makedirs(df3_output)

skipped = []
scientific_names_df3 = []

for label in os.listdir(df3):
    label_path = os.path.join(df3, label)
    if os.path.isdir(label_path):
        if label in mapping:
            scientific_name = standardize_name(mapping[label])
            scientific_names_df3.append(scientific_name)
            dest_path = os.path.join(df3_output, scientific_name)
            shutil.copytree(label_path, dest_path, dirs_exist_ok=True)
            print(f"Copied: {label} --> {scientific_name}")
        else:
            skipped.append(label)
            print(f"SKIPPED: {label}")

scientific_names_df3 = list(set(scientific_names_df3))
print("\nSkipped folders:", skipped)
print("\nFinal scientific names list df3:")
print(scientific_names_df3)
# Out:
# Copied: Tecoma --> tecoma_stans
# Copied: Malabar_Nut --> adhatoda_vasica
# Copied: Curry --> murraya_koenigii
# Copied: Drumstick --> moringa_oleifera
# Copied: Tomato --> solanum_lycopersicum
# Copied: Lemongrass --> cymbopogon_citratus
# Copied: Ginger --> zingiber_officinale
# Copied: Chilly --> capsicum_frutescens
# Copied: Nelavembu --> andrographis_paniculata
# Copied: Raddish --> raphanus_sativus
# Copied: Nooni --> morinda_citrifolia
# Copied: Jackfruit --> artocarpus_heterophyllus
# Copied: Turmeric --> curcuma_longa
# Copied: Palak(Spinach) --> spinacia_oleracea
# Copied: Honge --> millettia_pinnata
# Copied: Mint --> mentha
# Copied: Pumpkin --> cucurbita_moschata
# Copied: Lantana --> lantana_camara
# Copied: Jasmine --> jasminum
# Copied: Castor --> ricinus_communis
# Copied: Papaya --> carica_papaya
# Copied: Sapota --> manilkara_zapota
# Copied: Kambajala --> cassia_tora
# SKIPPED: Kasambruga
# SKIPPED: Badipala
# Copied: Neem --> azadirachta_indica
# Copied: Guava --> psidium_guajava
# Copied: Bringaraja --> eclipta_prostrata
# Copied: kamakasturi --> ocimum_basilicum
# Copied: Coriender --> coriandrum_sativum
# Copied: Coffee --> coffea
# Copied: ashoka --> saraca_asoca
# Copied: Tulsi --> ocimum_tenuiflorum
# Copied: Pea --> pisum
# Copied: Seethapala --> annona_reticulata
# Copied: Caricature --> graptophyllum_pictum
# Copied: Citron lime (herelikai) --> citrus_medica
# Copied: Catharanthus --> catharanthus_roseus
# Copied: Astma_weed --> euphorbia_hirta
# Copied: Pepper --> piper_nigrum
# Copied: Balloon_Vine --> cardiospermum_halicacabum
# Copied: Hibiscus --> hibiscus_rosa_sinensis
# Copied: Bhrami --> bacopa_monnieri
# Copied: Pomoegranate --> punica_granatum
# Copied: Aloevera --> aloe_barbadensis
# SKIPPED: Chakte
# Copied: Eucalyptus --> eucalyptus_globulus
# Copied: Beans --> phaseolus
# Copied: Insulin --> chamaecostus_cuspidatus
# Copied: camphor --> cinnamomum_camphora
# Copied: Padri --> radermachera_xylocarpa
# Copied: Parijatha --> nyctanthes_arbor_tristis
# Copied: Marigold --> tagetes_erecta
# Copied: Taro --> colocasia_esculenta
# Copied: Spinach1 --> spinacia_oleracea
# Copied: Bamboo --> bambusoideae
# Copied: Amla --> phyllanthus_emblica
# Copied: Arali --> ficus_religiosa
# Copied: kepala --> ixora_undulata
# Copied: Globe Amarnath --> gomphrena_globosa
# Copied: Ganigale --> calotropis_gigantea
# Copied: Lemon --> citrus_limon
# Copied: Common rue(naagdalli) --> ruta_graveolens
# Copied: Ekka --> calotropis_gigantea
# Copied: Betel --> piper_betle
# Copied: Tamarind --> tamarindus_indica
# Copied: Henna --> lawsonia_inermis
# Copied: Gasagase --> papaver_somniferum
# Copied: Doddpathre --> coleus_amboinicus
# Copied: Malabar_Spinach --> basella_alba
# Copied: Rose --> rosa
# Copied: Amruthaballi --> tinospora_cordifolia
# Copied: Kohlrabi --> brassica_oleracea_var._gongylodes
# Copied: Nerale --> syzygium_cumini
# Copied: Mango --> mangifera_indica
# Copied: Onion --> allium_cepa
# Copied: Thumbe --> leucas_aspera
# Copied: Sampige --> magnolia_champaca
# Copied: Ganike --> solanum_nigrum
# SKIPPED: Seethaashoka
#
# Skipped folders: ['Kasambruga', 'Badipala', 'Chakte', 'Seethaashoka']
#
# Final scientific names list df3:
# ['annona_reticulata', 'punica_granatum', 'piper_betle', 'radermachera_xylocarpa', 'ocimum_tenuiflorum', 'carica_papaya', 'citrus_limon', 'curcuma_longa', 'manilkara_zapota', 'citrus_medica', 'chamaecostus_cuspidatus', 'tecoma_stans', 'eucalyptus_globulus', 'millettia_pinnata', 'murraya_koenigii', 'tagetes_erecta', 'rosa', 'ricinus_communis', 'nyctanthes_arbor_tristis', 'hibiscus_rosa_sinensis', 'lawsonia_inermis', 'mentha', 'artocarpus_heterophyllus', 'syzygium_cumini', 'pisum', 'psidium_guajava', 'andrographis_paniculata', 'phyllanthus_emblica', 'coleus_amboinicus', 'cucurbita_moschata', 'saraca_asoca', 'piper_nigrum', 'basella_alba', 'leucas_aspera', 'lantana_camara', 'phaseolus', 'coriandrum_sativum', 'azadirachta_indica', 'cassia_tora', 'cymbopogon_citratus', 'jasminum', 'tamarindus_indica', 'magnolia_champaca', 'ficus_religiosa', 'gomphrena_globosa', 'solanum_nigrum', 'eclipta_prostrata', 'euphorbia_hirta', 'moringa_oleifera', 'ruta_graveolens', 'bambusoideae', 'graptophyllum_pictum', 'papaver_somniferum', 'raphanus_sativus', 'bacopa_monnieri', 'ixora_undulata', 'tinospora_cordifolia', 'brassica_oleracea_var._gongylodes', 'coffea', 'calotropis_gigantea', 'catharanthus_roseus', 'allium_cepa', 'adhatoda_vasica', 'colocasia_esculenta', 'mangifera_indica', 'zingiber_officinale', 'cinnamomum_camphora', 'morinda_citrifolia', 'ocimum_basilicum', 'capsicum_frutescens', 'aloe_barbadensis', 'spinacia_oleracea', 'solanum_lycopersicum', 'cardiospermum_halicacabum']

# %%
import os
import shutil

df4 = "/kaggle/input/datasets/saitejaswinichikoti/south-indian-medicinal-plant-dataset/SIMPD V1 South Indian Medicinal Plants dataset (Version 1)"
df4_output = "/kaggle/working/SIMPD_Dataset"

manual_fixes = {
    "ouretlanata": "ouret_lanata",
    "eclipta_prostrate": "eclipta_prostrata",
    "justica_adhatoda": "justicia_adhatoda",
    "senna_atriculata": "senna_auriculata",
    "eichhornia_crassipes": "eichhornia_crassipes",
    "hibiscus_rosasinensis": "hibiscus_rosa_sinensis",
    "aloe_barbadensis_miller": "aloe_barbadensis",
}

def standardize_name(name):
    std = name.replace("-", "_").replace(" ", "_").lower().strip()
    if std in manual_fixes:
        std = manual_fixes[std]
    return std

if os.path.exists(df4_output):
    shutil.rmtree(df4_output)
os.makedirs(df4_output)

scientific_names_df4 = []

for label in os.listdir(df4):
    label_path = os.path.join(df4, label)
    if os.path.isdir(label_path):
        scientific_name = standardize_name(label)
        scientific_names_df4.append(scientific_name)
        dest_path = os.path.join(df4_output, scientific_name)
        shutil.copytree(label_path, dest_path)
        print(f"Copied: {label} --> {scientific_name}")

scientific_names_df4 = list(set(scientific_names_df4))
print("\nFinal scientific names list df4:")
print(scientific_names_df4)
# Out:
# Copied: Hibiscus Rosasinensis --> hibiscus_rosa_sinensis
# Copied: Curcuma longa --> curcuma_longa
# Copied: Abutilon Indicum --> abutilon_indicum
# Copied: Ziziphus mauritiana --> ziziphus_mauritiana
# Copied: Ouretlanata --> ouret_lanata
# Copied: Canna indica --> canna_indica
# Copied: Ocimum tenuiflorum --> ocimum_tenuiflorum
# Copied: Trifolium Repens --> trifolium_repens
# Copied: Eclipta prostrate --> eclipta_prostrata
# Copied: Phyllanthus amarus --> phyllanthus_amarus
# Copied: Calotropis gigantea --> calotropis_gigantea
# Copied: Murraya koenigii --> murraya_koenigii
# Copied: Ixora coccinea --> ixora_coccinea
# Copied: Sesbania grandiflora --> sesbania_grandiflora
# Copied: Ricinus communis --> ricinus_communis
# Copied: Justica adhatoda --> justicia_adhatoda
# Copied: Aloe barbadensis miller --> aloe_barbadensis
# Copied: Senna Atriculata --> senna_auriculata
# Copied: Cissus quadrangularis --> cissus_quadrangularis
# Copied: Eichhornia Crassipes --> eichhornia_crassipes
#
# Final scientific names list df4:
# ['justicia_adhatoda', 'cissus_quadrangularis', 'ocimum_tenuiflorum', 'curcuma_longa', 'murraya_koenigii', 'canna_indica', 'ricinus_communis', 'hibiscus_rosa_sinensis', 'phyllanthus_amarus', 'eichhornia_crassipes', 'ziziphus_mauritiana', 'sesbania_grandiflora', 'ouret_lanata', 'eclipta_prostrata', 'ixora_coccinea', 'senna_auriculata', 'trifolium_repens', 'calotropis_gigantea', 'abutilon_indicum', 'aloe_barbadensis']

# %%
set_df2 = set(scientific_names_df2)
set_df3 = set(scientific_names_df3)
set_df4 = set(scientific_names_df4)

# Individual sizes
print("Size of df2:", len(set_df2))
print("Size of df3:", len(set_df3))
print("Size of df4:", len(set_df4))

# Common in all three
common_all = set_df2 & set_df3 & set_df4
print("\nCommon in ALL three:", len(common_all), sorted(common_all))

# Common in pairs ( common only between pairs not including the other one )
common_df2_df3 = set_df2 & set_df3 - set_df4
print("\nCommon in df2 & df3 only:", len(common_df2_df3), sorted(common_df2_df3))

common_df2_df4 = set_df2 & set_df4 - set_df3
print("\nCommon in df2 & df4 only:", len(common_df2_df4), sorted(common_df2_df4))

common_df3_df4 = set_df3 & set_df4 - set_df2
print("\nCommon in df3 & df4 only:", len(common_df3_df4), sorted(common_df3_df4))

# Union
union_all = set_df2 | set_df3 | set_df4
print("\nTotal unique after merging:", len(union_all))
print("All classes:", sorted(union_all))
# Out:
# Size of df2: 30
# Size of df3: 74
# Size of df4: 20
#
# Common in ALL three: 3 ['hibiscus_rosa_sinensis', 'murraya_koenigii', 'ocimum_tenuiflorum']
#
# Common in df2 & df3 only: 14 ['artocarpus_heterophyllus', 'azadirachta_indica', 'basella_alba', 'citrus_limon', 'ficus_religiosa', 'jasminum', 'mangifera_indica', 'mentha', 'moringa_oleifera', 'nyctanthes_arbor_tristis', 'piper_betle', 'psidium_guajava', 'punica_granatum', 'syzygium_cumini']
#
# Common in df2 & df4 only: 0 []
#
# Common in df3 & df4 only: 5 ['aloe_barbadensis', 'calotropis_gigantea', 'curcuma_longa', 'eclipta_prostrata', 'ricinus_communis']
#
# Total unique after merging: 99
# All classes: ['abutilon_indicum', 'adhatoda_vasica', 'allium_cepa', 'aloe_barbadensis', 'alpinia_galanga', 'amaranthus_viridis', 'andrographis_paniculata', 'annona_reticulata', 'artocarpus_heterophyllus', 'azadirachta_indica', 'bacopa_monnieri', 'bambusoideae', 'basella_alba', 'brassica_juncea', 'brassica_oleracea_var._gongylodes', 'calotropis_gigantea', 'canna_indica', 'capsicum_frutescens', 'cardiospermum_halicacabum', 'carica_papaya', 'carissa_carandas', 'cassia_tora', 'catharanthus_roseus', 'chamaecostus_cuspidatus', 'cinnamomum_camphora', 'cissus_quadrangularis', 'citrus_limon', 'citrus_medica', 'coffea', 'coleus_amboinicus', 'colocasia_esculenta', 'coriandrum_sativum', 'cucurbita_moschata', 'curcuma_longa', 'cymbopogon_citratus', 'eclipta_prostrata', 'eichhornia_crassipes', 'eucalyptus_globulus', 'euphorbia_hirta', 'ficus_auriculata', 'ficus_religiosa', 'gomphrena_globosa', 'graptophyllum_pictum', 'hibiscus_rosa_sinensis', 'ixora_coccinea', 'ixora_undulata', 'jasminum', 'justicia_adhatoda', 'lantana_camara', 'lawsonia_inermis', 'leucas_aspera', 'magnolia_champaca', 'mangifera_indica', 'manilkara_zapota', 'mentha', 'millettia_pinnata', 'morinda_citrifolia', 'moringa_oleifera', 'muntingia_calabura', 'murraya_koenigii', 'nerium_oleander', 'nyctanthes_arbor_tristis', 'ocimum_basilicum', 'ocimum_tenuiflorum', 'ouret_lanata', 'papaver_somniferum', 'phaseolus', 'phyllanthus_amarus', 'phyllanthus_emblica', 'piper_betle', 'piper_nigrum', 'pisum', 'plectranthus_amboinicus', 'pongamia_pinnata', 'psidium_guajava', 'punica_granatum', 'radermachera_xylocarpa', 'raphanus_sativus', 'ricinus_communis', 'rosa', 'ruta_graveolens', 'santalum_album', 'saraca_asoca', 'senna_auriculata', 'sesbania_grandiflora', 'solanum_lycopersicum', 'solanum_nigrum', 'spinacia_oleracea', 'syzygium_cumini', 'syzygium_jambos', 'tabernaemontana_divaricata', 'tagetes_erecta', 'tamarindus_indica', 'tecoma_stans', 'tinospora_cordifolia', 'trifolium_repens', 'trigonella_foenum_graecum', 'zingiber_officinale', 'ziziphus_mauritiana']

# %%
import os
import shutil

df2_output = "/kaggle/working/Medicinal_Leaf_Dataset"
df3_output = "/kaggle/working/Mendeley_Dataset"
df4_output = "/kaggle/working/SIMPD_Dataset"
merged_output = "/kaggle/working/Merged_Dataset"

if os.path.exists(merged_output):
    shutil.rmtree(merged_output)
os.makedirs(merged_output)

def merge_folder_symlink(src, dest):
    os.makedirs(dest, exist_ok=True)
    for img in os.listdir(src):
        src_img = os.path.join(src, img)
        dst_img = os.path.join(dest, img)
        if os.path.isfile(src_img):
            if os.path.exists(dst_img):
                base, ext = os.path.splitext(img)
                counter = 1
                while os.path.exists(dst_img):
                    dst_img = os.path.join(dest, f"{base}_{counter}{ext}")
                    counter += 1
            os.symlink(src_img, dst_img)

for source in [df2_output, df3_output, df4_output]:
    for folder in os.listdir(source):
        folder_path = os.path.join(source, folder)
        if os.path.isdir(folder_path):
            dest_path = os.path.join(merged_output, folder)
            merge_folder_symlink(folder_path, dest_path)

final_folders = sorted(os.listdir(merged_output))
print(f"Total classes: {len(final_folders)}")
for f in final_folders:
    count = len(os.listdir(os.path.join(merged_output, f)))
    print(f"{f}: {count} images")
# Out:
# Total classes: 99
# abutilon_indicum: 165 images
# adhatoda_vasica: 51 images
# allium_cepa: 92 images
# aloe_barbadensis: 263 images
# alpinia_galanga: 50 images
# amaranthus_viridis: 122 images
# andrographis_paniculata: 90 images
# annona_reticulata: 114 images
# artocarpus_heterophyllus: 166 images
# azadirachta_indica: 192 images
# bacopa_monnieri: 104 images
# bambusoideae: 118 images
# basella_alba: 182 images
# brassica_juncea: 34 images
# brassica_oleracea_var._gongylodes: 73 images
# calotropis_gigantea: 262 images
# canna_indica: 149 images
# capsicum_frutescens: 69 images
# cardiospermum_halicacabum: 61 images
# carica_papaya: 135 images
# carissa_carandas: 74 images
# cassia_tora: 59 images
# catharanthus_roseus: 134 images
# chamaecostus_cuspidatus: 89 images
# cinnamomum_camphora: 66 images
# cissus_quadrangularis: 134 images
# citrus_limon: 180 images
# citrus_medica: 99 images
# coffea: 83 images
# coleus_amboinicus: 142 images
# colocasia_esculenta: 69 images
# coriandrum_sativum: 115 images
# cucurbita_moschata: 92 images
# curcuma_longa: 149 images
# cymbopogon_citratus: 8 images
# eclipta_prostrata: 281 images
# eichhornia_crassipes: 202 images
# eucalyptus_globulus: 80 images
# euphorbia_hirta: 82 images
# ficus_auriculata: 50 images
# ficus_religiosa: 152 images
# gomphrena_globosa: 81 images
# graptophyllum_pictum: 76 images
# hibiscus_rosa_sinensis: 274 images
# ixora_coccinea: 114 images
# ixora_undulata: 76 images
# jasminum: 120 images
# justicia_adhatoda: 100 images
# lantana_camara: 76 images
# lawsonia_inermis: 80 images
# leucas_aspera: 74 images
# magnolia_champaca: 61 images
# mangifera_indica: 165 images
# manilkara_zapota: 45 images
# mentha: 232 images
# millettia_pinnata: 113 images
# morinda_citrifolia: 72 images
# moringa_oleifera: 133 images
# muntingia_calabura: 56 images
# murraya_koenigii: 346 images
# nerium_oleander: 62 images
# nyctanthes_arbor_tristis: 106 images
# ocimum_basilicum: 67 images
# ocimum_tenuiflorum: 331 images
# ouret_lanata: 119 images
# papaver_somniferum: 79 images
# phaseolus: 97 images
# phyllanthus_amarus: 111 images
# phyllanthus_emblica: 67 images
# piper_betle: 162 images
# piper_nigrum: 8 images
# pisum: 47 images
# plectranthus_amboinicus: 48 images
# pongamia_pinnata: 61 images
# psidium_guajava: 193 images
# punica_granatum: 154 images
# radermachera_xylocarpa: 73 images
# raphanus_sativus: 40 images
# ricinus_communis: 238 images
# rosa: 106 images
# ruta_graveolens: 67 images
# santalum_album: 58 images
# saraca_asoca: 81 images
# senna_auriculata: 125 images
# sesbania_grandiflora: 91 images
# solanum_lycopersicum: 62 images
# solanum_nigrum: 63 images
# spinacia_oleracea: 219 images
# syzygium_cumini: 101 images
# syzygium_jambos: 56 images
# tabernaemontana_divaricata: 56 images
# tagetes_erecta: 93 images
# tamarindus_indica: 176 images
# tecoma_stans: 69 images
# tinospora_cordifolia: 91 images
# trifolium_repens: 100 images
# trigonella_foenum_graecum: 36 images
# zingiber_officinale: 82 images
# ziziphus_mauritiana: 92 images
