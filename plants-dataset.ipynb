# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import os
for root, dirs, files in os.walk("/kaggle/input"):
    level = root.replace("/kaggle/input", "").count(os.sep)
    print("  " * level + os.path.basename(root) + "/")
# Out:
# input/
#   datasets/
#     saitejaswinichikoti/
#       dataset1/
#         Plantes/
#           Salvia officinalis/
#           acaciaehrenbergiana/
#           traganum nudatum/
#           Foeniculum vulgare P.Mill/
#           bubonuim graveolens/
#           Matricaria-chamomilla/
#           Ferula communis L/
#           Glycyrrhiza glabra/
#           Pistacia atlantica Desf/
#           Eugenia-caryophyllata-thumb/
#           maerua crassifolia/
#           aristida plumosa/
#           Mentha viridis/
#           echuim plantagineum/
#           Chrysanthemum/
#           زراوند/
#           Ammodaucus leucotrichus coss et Dur/
#           Ajuga iva/
#           Eucalybtus-torquata/
#           cynodon dactylon/
#           Mallus-communis/
#           رجل الحمام/
#           هليون/
#           Leucas martinicensis/
#           pergularia tamantosa/
#           Carum carvi L/
#           kikchia aygeapciaca/
#           heliotropium erosum/
#           Euphorbia-granulata/
#           Echinacea/
#           capparis decidua/
#           Prunus-amygdalus/
#           zyzuphus lotus/
#           neurada procymbense/
#           licium intricatum/
#           Cyminum Cuminum L/
#           الزراوند قليل العروق/
#           rubia-peregrina/
#           Apium graveolens L/
#           Helianthus-annuus/
#           atriplex halimus/
#           Origanum majorana/
#           Olea-europaea/
#           chenopoduim murale/
#           brochia cinéra/
#           Rhus tripartitum DC/
#           zilla spinosa/
#           zyghlophilum wat/
#           acacia raddiana/
#           fagonia glutinosa/
#           Salvia divers/
#           linaria sagitata/
#           Cynara-scolymus/
#           Daucus carota L/
#           tamaris boveana/
#           cylyusea hexagyna/
#           satureja calamintha/
#           Léonotis nepetifolia/
#           Populus nigra/
#           Daucus crinitus Desf/
#           tribulus allatus/
#           salsola langifolia/
#           Atemisia/
#           frankenia corombosa/
#           elizadia calycina/
#           Querqus suber/
#           Cichorium-intybus/
#           mensonia nivea/
#           euphorbia echunus/
#           Lupinus-albus/
#           cenchrus biflorus/
#           Centaurea pungens/
#           Lavandulastoechas/
#           Nerium oleanda L/
#           balanites aegiptiaca/
#           echuim sp/
#           zygophylum simplex/
#           عنصل بحري/
#           قاع قلا/
#           Myrtus-communis/
#           farsetia ramosissima/
#           برزطم/
#           limonium ovalifolium/
#           Rosa-centifolia-Mill/
#           launea residifolia/
#           dipcadi panozii/
#           diplotaxis/
#           aizoon canariensis/
#           polypogon monseliensis/
#           anastatica hierochentica/
#           Teucriumpolium/
#           الخدنجل/
#           fraxinus-angustifolia/
#           heliotropium bacciferum/
#           لويزة/
#           periploca angustifolia/
#           nucularia perrini/
#           lotus glinoides/
#           hamada scoparia/
#           Pistacia lentiscus L/
#           pissenlit/
#           Prunus-armenica/
#           astragalus vogelii/
#           senesio anteu/
#           fagonia zilloides/
#           Querqus faginea/
#           thymus/
#           Lens-culinaris/
#           Polygonum maritimum/
#           سكينجبير/
#           salsola tetragona/
#           cleomé arabica/
#           linum usitatissimum/
#           lotus jolyi/
#           anabasis arcti/
#           panicum turgidum/
#           برواك/
#           Salix-alba/
#           tamarix bovinea/
#           gnaphalium lutheolbum/
#           androcybiom graminum/
#           Trigonella-foenum/
#           Tagetes/
#           nitraria retusa/
#           Marrubium vulgare/
#           Rosmarinusofficinalis/
#           opophytum teurkauffii/
#           Pimpinella anisum L/
#           zygophyllum getulum/
#           pancratium trianthum/
#           deverra scoparia/
#           Phillyrea-angustifolia/
#           salsola baryosma/
#           salvia aygepciaca/
#           launea arborescens/
#           ononis tounefortii/
#           Eriobotrya-japonica/
#           salsola vermiculata/
#           Mentha suaveolens Ehr/
#           medicago lacianata/
#           Cicer-arietinum/
#           antirinum ramossisimum/
#           gailounia reboudiana/
#           Origanum compactum Benth/
#           Ceratoniasiliqua/
#           hippocrepis multisiliquoa/
#           crotalaria saharae/
#           euphorbia-dracunoluides/
#           Coffea-arabica/
#           Ptychotis verticillata L/
#           retama retam/
#           launea nudcaulis/
#           atractylis babelii/
#           Ocinum basillicum/
#           Lavanduladentata/
#           erryngium maritimum/
#           citrillus colocentis/
#           traganum moquini/
#           Petroselinum sativum Hoffm/
#           salsola tetranda/
#           Vicia-faba/
#           teucrium chardonianum/
#           gymnocarpuse decander/
#           سكوم/
#       south-indian-medicinal-plant-dataset/
#         SIMPD V1 South Indian Medicinal Plants dataset (Version 1)/
#           Hibiscus Rosasinensis/
#           Curcuma longa/
#           Abutilon Indicum/
#           Ziziphus mauritiana/
#           Ouretlanata/
#           Canna indica/
#           Ocimum tenuiflorum/
#           Trifolium Repens/
#           Eclipta prostrate/
#           Phyllanthus amarus/
#           Calotropis gigantea/
#           Murraya koenigii/
#           Ixora coccinea/
#           Sesbania grandiflora/
#           Ricinus communis/
#           Justica adhatoda/
#           Aloe barbadensis miller/
#           Senna Atriculata/
#           Cissus quadrangularis/
#           Eichhornia Crassipes/
#       medicinal-leaf-dataset/
#         Medicinal Leaf Dataset/
#           Segmented Medicinal Leaf Images/
#             Murraya Koenigii (Curry)/
#             Nyctanthes Arbor-tristis (Parijata)/
#             Plectranthus Amboinicus (Mexican Mint)/
#             Punica Granatum (Pomegranate)/
#             Ficus Religiosa (Peepal Tree)/
#             Muntingia Calabura (Jamaica Cherry-Gasagase)/
#             Tabernaemontana Divaricata (Crape Jasmine)/
#             Psidium Guajava (Guava)/
#             Ocimum Tenuiflorum (Tulsi)/
#             Moringa Oleifera (Drumstick)/
#             Brassica Juncea (Indian Mustard)/
#             Nerium Oleander (Oleander)/
#             Carissa Carandas (Karanda)/
#             Santalum Album (Sandalwood)/
#             Artocarpus Heterophyllus (Jackfruit)/
#             Mentha (Mint)/
#             Citrus Limon (Lemon)/
#             Alpinia Galanga (Rasna)/
#             Piper Betle (Betel)/
#             Basella Alba (Basale)/
#             Pongamia Pinnata (Indian Beech)/
#             Mangifera Indica (Mango)/
#             Amaranthus Viridis (Arive-Dantu)/
#             Trigonella Foenum-graecum (Fenugreek)/
#             Jasminum (Jasmine)/
#             Syzygium Jambos (Rose Apple)/
#             Ficus Auriculata (Roxburgh fig)/
#             Azadirachta Indica (Neem)/
#             Syzygium Cumini (Jamun)/
#             Hibiscus Rosa-sinensis/
#       mendeley/
#         Indian Medicinal Leaves Image Datasets/
#           Medicinal plant dataset/
#             Nooni/
#             Nithyapushpa/
#             Basale/
#             Pomegranate/
#             Honge/
#             Lemon_grass/
#             Mint/
#             Betel_Nut/
#             Nagadali/
#             Curry_Leaf/
#             Jasmine/
#             Castor/
#             Sapota/
#             Neem/
#             Ashoka/
#             Brahmi/
#             Amruta_Balli/
#             Pappaya/
#             Pepper/
#             Wood_sorel/
#             Gauva/
#             Hibiscus/
#             Ashwagandha/
#             Aloevera/
#             Raktachandini/
#             Insulin/
#             Bamboo/
#             Amla/
#             Arali/
#             Geranium/
#             Avacado/
#             Lemon/
#             Ekka/
#             Betel/
#             Henna/
#             Doddapatre/
#             Rose/
#             Mango/
#             Tulasi/
#             Ganike/
#           Medicinal Leaf dataset/
#             Tecoma/
#             Malabar_Nut/
#             Curry/
#             Drumstick/
#             Tomato/
#             Lemongrass/
#             Ginger/
#             Chilly/
#             Nelavembu/
#             Raddish/
#             Nooni/
#             Jackfruit/
#             Turmeric/
#             Palak(Spinach)/
#             Honge/
#             Mint/
#             Pumpkin/
#             Lantana/
#             Jasmine/
#             Castor/
#             Papaya/
#             Sapota/
#             Kambajala/
#             Kasambruga/
#             Badipala/
#             Neem/
#             Guava/
#             Bringaraja/
#             kamakasturi/
#             Coriender/
#             Coffee/
#             ashoka/
#             Tulsi/
#             Pea/
#             Seethapala/
#             Caricature/
#             Citron lime (herelikai)/
#             Catharanthus/
#             Astma_weed/
#             Pepper/
#             Balloon_Vine/
#             Hibiscus/
#             Bhrami/
#             Pomoegranate/
#             Aloevera/
#             Chakte/
#             Eucalyptus/
#             Beans/
#             Insulin/
#             camphor/
#             Padri/
#             Parijatha/
#             Marigold/
#             Taro/
#             Spinach1/
#             Bamboo/
#             Amla/
#             Arali/
#             kepala/
#             Globe Amarnath/
#             Ganigale/
#             Lemon/
#             Common rue(naagdalli)/
#             Ekka/
#             Betel/
#             Tamarind/
#             Henna/
#             Gasagase/
#             Doddpathre/
#             Malabar_Spinach/
#             Rose/
#             Amruthaballi/
#             Kohlrabi/
#             Nerale/
#             Mango/
#             Onion/
#             Thumbe/
#             Sampige/
#             Ganike/
#             Seethaashoka/

# %%
import os
dataset_path = "/kaggle/input/datasets/saitejaswinichikoti/dataset1/Plantes"
for label in os.listdir(dataset_path):
    label_path = os.path.join(dataset_path, label)
    if os.path.isdir(label_path):
        count = len(os.listdir(label_path))
        print(label, count)
# Out:
# Salvia officinalis 4
# acaciaehrenbergiana 5
# traganum nudatum 4
# Foeniculum vulgare P.Mill 38
# bubonuim graveolens 6
# Matricaria-chamomilla 32
# Ferula communis L 43
# Glycyrrhiza glabra 28
# Pistacia atlantica Desf 21
# Eugenia-caryophyllata-thumb 13
# maerua crassifolia 6
# aristida plumosa 18
# Mentha viridis 4
# echuim plantagineum 9
# Chrysanthemum 10
# زراوند 76
# Ammodaucus leucotrichus coss et Dur 9
# Ajuga iva 26
# Eucalybtus-torquata 40
# cynodon dactylon 8
# Mallus-communis 36
# رجل الحمام 16
# هليون 63
# Leucas martinicensis 19
# pergularia tamantosa 58
# Carum carvi L 44
# kikchia aygeapciaca 5
# heliotropium erosum 4
# Euphorbia-granulata 30
# Echinacea 33
# capparis decidua 13
# Prunus-amygdalus 51
# zyzuphus lotus 6
# neurada procymbense 7
# licium intricatum 4
# Cyminum Cuminum L 9
# الزراوند قليل العروق 90
# rubia-peregrina 51
# Apium graveolens L 12
# Helianthus-annuus 38
# atriplex halimus 5
# Origanum majorana 37
# Olea-europaea 30
# chenopoduim murale 38
# brochia cinéra 6
# Rhus tripartitum DC 32
# zilla spinosa 5
# zyghlophilum wat 3
# acacia raddiana 25
# fagonia glutinosa 20
# Salvia divers 4
# linaria sagitata 12
# Cynara-scolymus 28
# Daucus carota L 30
# tamaris boveana 4
# cylyusea hexagyna 3
# satureja calamintha 4
# Léonotis nepetifolia 32
# Populus nigra 90
# Daucus crinitus Desf 21
# tribulus allatus 4
# salsola langifolia 25
# Atemisia 25
# frankenia corombosa 24
# elizadia calycina 5
# Querqus suber 39
# Cichorium-intybus 29
# mensonia nivea 6
# euphorbia echunus 28
# Lupinus-albus 37
# cenchrus biflorus 20
# Centaurea pungens 23
# Lavandulastoechas 30
# Nerium oleanda L 40
# balanites aegiptiaca 16
# echuim sp 8
# zygophylum simplex 5
# عنصل بحري 41
# قاع قلا 4
# Myrtus-communis 52
# farsetia ramosissima 6
# برزطم 46
# limonium ovalifolium 3
# Rosa-centifolia-Mill 26
# launea residifolia 7
# dipcadi panozii 18
# diplotaxis 20
# aizoon canariensis 21
# polypogon monseliensis 37
# anastatica hierochentica 7
# Teucriumpolium 4
# الخدنجل 4
# fraxinus-angustifolia 35
# heliotropium bacciferum 23
# لويزة 4
# periploca angustifolia 73
# nucularia perrini 6
# lotus glinoides 21
# hamada scoparia 3
# Pistacia lentiscus L 49
# pissenlit 4
# Prunus-armenica 50
# astragalus vogelii 8
# senesio anteu 7
# fagonia zilloides 28
# Querqus faginea 30
# thymus 4
# Lens-culinaris 38
# Polygonum maritimum 41
# سكينجبير 4
# salsola tetragona 6
# cleomé arabica 55
# linum usitatissimum 47
# lotus jolyi 6
# anabasis arcti 5
# panicum turgidum 4
# برواك 43
# Salix-alba 51
# tamarix bovinea 4
# gnaphalium lutheolbum 21
# androcybiom graminum 3
# Trigonella-foenum 4
# Tagetes 24
# nitraria retusa 5
# Marrubium vulgare 34
# Rosmarinusofficinalis 64
# opophytum teurkauffii 28
# Pimpinella anisum L 37
# zygophyllum getulum 5
# pancratium trianthum 36
# deverra scoparia 26
# Phillyrea-angustifolia 72
# salsola baryosma 21
# salvia aygepciaca 6
# launea arborescens 3
# ononis tounefortii 6
# Eriobotrya-japonica 54
# salsola vermiculata 7
# Mentha suaveolens Ehr 4
# medicago lacianata 5
# Cicer-arietinum 58
# antirinum ramossisimum 18
# gailounia reboudiana 5
# Origanum compactum Benth 4
# Ceratoniasiliqua 39
# hippocrepis multisiliquoa 20
# crotalaria saharae 18
# euphorbia-dracunoluides 13
# Coffea-arabica 52
# Ptychotis verticillata L 15
# retama retam 29
# launea nudcaulis 29
# atractylis babelii 20
# Ocinum basillicum 4
# Lavanduladentata 19
# erryngium maritimum 30
# citrillus colocentis 26
# traganum moquini 4
# Petroselinum sativum Hoffm 2
# salsola tetranda 5
# Vicia-faba 4
# teucrium chardonianum 6
# gymnocarpuse decander 7
# سكوم 49

# %%
import os
dataset_path = "/kaggle/input/datasets/saitejaswinichikoti/mendeley/Indian Medicinal Leaves Image Datasets/Medicinal plant dataset"
for label in os.listdir(dataset_path):
    label_path = os.path.join(dataset_path, label)
    if os.path.isdir(label_path):
        count = len(os.listdir(label_path))
        print(label, count)
# Out:
# Nooni 146
# Nithyapushpa 146
# Basale 146
# Pomegranate 146
# Honge 146
# Lemon_grass 146
# Mint 153
# Betel_Nut 146
# Nagadali 152
# Curry_Leaf 146
# Jasmine 187
# Castor 160
# Sapota 146
# Neem 146
# Ashoka 146
# Brahmi 146
# Amruta_Balli 146
# Pappaya 146
# Pepper 146
# Wood_sorel 146
# Gauva 146
# Hibiscus 165
# Ashwagandha 146
# Aloevera 164
# Raktachandini 146
# Insulin 146
# Bamboo 146
# Amla 146
# Arali 146
# Geranium 146
# Avacado 146
# Lemon 146
# Ekka 146
# Betel 151
# Henna 150
# Doddapatre 146
# Rose 168
# Mango 146
# Tulasi 146
# Ganike 115

# %%
import os
dataset_path = "/kaggle/input/datasets/saitejaswinichikoti/medicinal-leaf-dataset/Medicinal Leaf Dataset/Segmented Medicinal Leaf Images"
for label in os.listdir(dataset_path):
    label_path = os.path.join(dataset_path, label)
    if os.path.isdir(label_path):
        count = len(os.listdir(label_path))
        print(label, count)
# Out:
# Murraya Koenigii (Curry) 60
# Nyctanthes Arbor-tristis (Parijata) 40
# Plectranthus Amboinicus (Mexican Mint) 48
# Punica Granatum (Pomegranate) 79
# Ficus Religiosa (Peepal Tree) 63
# Muntingia Calabura (Jamaica Cherry-Gasagase) 56
# Tabernaemontana Divaricata (Crape Jasmine) 56
# Psidium Guajava (Guava) 65
# Ocimum Tenuiflorum (Tulsi) 52
# Moringa Oleifera (Drumstick) 77
# Brassica Juncea (Indian Mustard) 34
# Nerium Oleander (Oleander) 62
# Carissa Carandas (Karanda) 74
# Santalum Album (Sandalwood) 58
# Artocarpus Heterophyllus (Jackfruit) 56
# Mentha (Mint) 97
# Citrus Limon (Lemon) 57
# Alpinia Galanga (Rasna) 50
# Piper Betle (Betel) 48
# Basella Alba (Basale) 103
# Pongamia Pinnata (Indian Beech) 61
# Mangifera Indica (Mango) 62
# Amaranthus Viridis (Arive-Dantu) 122
# Trigonella Foenum-graecum (Fenugreek) 36
# Jasminum (Jasmine) 71
# Syzygium Jambos (Rose Apple) 56
# Ficus Auriculata (Roxburgh fig) 50
# Azadirachta Indica (Neem) 60
# Syzygium Cumini (Jamun) 39
# Hibiscus Rosa-sinensis 43

# %%
import os
dataset_path = "/kaggle/input/datasets/saitejaswinichikoti/south-indian-medicinal-plant-dataset/SIMPD V1 South Indian Medicinal Plants dataset (Version 1)"
for label in os.listdir(dataset_path):
    label_path = os.path.join(dataset_path, label)
    if os.path.isdir(label_path):
        count = len(os.listdir(label_path))
        print(label, count)
# Out:
# Hibiscus Rosasinensis 113
# Curcuma longa 110
# Abutilon Indicum 165
# Ziziphus mauritiana 92
# Ouretlanata 119
# Canna indica 149
# Ocimum tenuiflorum 102
# Trifolium Repens 100
# Eclipta prostrate 208
# Phyllanthus amarus 111
# Calotropis gigantea 106
# Murraya koenigii 118
# Ixora coccinea 114
# Sesbania grandiflora 91
# Ricinus communis 109
# Justica adhatoda 100
# Aloe barbadensis miller 145
# Senna Atriculata 125
# Cissus quadrangularis 134
# Eichhornia Crassipes 202

# %%
#kaggle([medicinal plants,leafs ], 164 dir , scientific name)
df1 = "/kaggle/input/datasets/saitejaswinichikoti/dataset1/Plantes"
#Medicinal_leaf_dataset(leafs , 30 dir ,scientific name(common name))
df2 = "/kaggle/input/datasets/saitejaswinichikoti/medicinal-leaf-dataset/Medicinal Leaf Dataset/Segmented Medicinal Leaf Images"
#Mendeley[ayurleaf](leafs , 80 dir , common name)
df3 = "/kaggle/input/datasets/saitejaswinichikoti/mendeley/Indian Medicinal Leaves Image Datasets/Medicinal Leaf dataset"
#SIMPD(mixed , 20 dir , scientific name)
df4 = "/kaggle/input/datasets/saitejaswinichikoti/south-indian-medicinal-plant-dataset/SIMPD V1 South Indian Medicinal Plants dataset (Version 1)"
